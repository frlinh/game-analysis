# %%
import pandas as pd
from pathlib import Path
import numpy as np

# %%
#url = "https://raw.githubusercontent.com/frlinh/game-analysis/dev-gaming-linhha/champion.json";
df = pd.read_json('https://raw.githubusercontent.com/frlinh/game-analysis/dev-gaming-linhha/champion.json')
df
# Out:
#              type             format  version  \
# Aatrox   champion  standAloneComplex  12.15.1
# Ahri     champion  standAloneComplex  12.15.1
# Akali    champion  standAloneComplex  12.15.1
# Akshan   champion  standAloneComplex  12.15.1
# Alistar  champion  standAloneComplex  12.15.1
# ...           ...                ...      ...
# Zeri     champion  standAloneComplex  12.15.1
# Ziggs    champion  standAloneComplex  12.15.1
# Zilean   champion  standAloneComplex  12.15.1
# Zoe      champion  standAloneComplex  12.15.1
# Zyra     champion  standAloneComplex  12.15.1
#
#                                                       data
# Aatrox   {'version': '12.15.1', 'id': 'Aatrox', 'key': ...
# Ahri     {'version': '12.15.1', 'id': 'Ahri', 'key': '1...
# Akali    {'version': '12.15.1', 'id': 'Akali', 'key': '...
# Akshan   {'version': '12.15.1', 'id': 'Akshan', 'key': ...
# Alistar  {'version': '12.15.1', 'id': 'Alistar', 'key':...
# ...

# %%
Data = df["data"]
Data
# Out:
# Aatrox     {'version': '12.15.1', 'id': 'Aatrox', 'key': ...
# Ahri       {'version': '12.15.1', 'id': 'Ahri', 'key': '1...
# Akali      {'version': '12.15.1', 'id': 'Akali', 'key': '...
# Akshan     {'version': '12.15.1', 'id': 'Akshan', 'key': ...
# Alistar    {'version': '12.15.1', 'id': 'Alistar', 'key':...
#                                  ...
# Zeri       {'version': '12.15.1', 'id': 'Zeri', 'key': '2...
# Ziggs      {'version': '12.15.1', 'id': 'Ziggs', 'key': '...
# Zilean     {'version': '12.15.1', 'id': 'Zilean', 'key': ...
# Zoe        {'version': '12.15.1', 'id': 'Zoe', 'key': '14...
# Zyra       {'version': '12.15.1', 'id': 'Zyra', 'key': '1...
# Name: data, Length: 161, dtype: object

# %%
Panda=pd.DataFrame.from_dict(Data)
Panda
# Out:
#                                                       data
# Aatrox   {'version': '12.15.1', 'id': 'Aatrox', 'key': ...
# Ahri     {'version': '12.15.1', 'id': 'Ahri', 'key': '1...
# Akali    {'version': '12.15.1', 'id': 'Akali', 'key': '...
# Akshan   {'version': '12.15.1', 'id': 'Akshan', 'key': ...
# Alistar  {'version': '12.15.1', 'id': 'Alistar', 'key':...
# ...                                                    ...
# Zeri     {'version': '12.15.1', 'id': 'Zeri', 'key': '2...
# Ziggs    {'version': '12.15.1', 'id': 'Ziggs', 'key': '...
# Zilean   {'version': '12.15.1', 'id': 'Zilean', 'key': ...
# Zoe      {'version': '12.15.1', 'id': 'Zoe', 'key': '14...
# Zyra     {'version': '12.15.1', 'id': 'Zyra', 'key': '1...
#
# [161 rows x 1 columns]

# %%
from pprint import pprint
new_data = dict()
for word,transl_dict in Data.items():
    for lbl, transl in transl_dict.items():
        if not(lbl in new_data.keys()):
            new_data[lbl] = dict()
        new_data[lbl][word] = transl

pprint(new_data)
# Out:
# {'blurb': {'Aatrox': 'Once honored defenders of Shurima against the Void, '
#                      'Aatrox and his brethren would eventually become an even '
#                      'greater threat to Runeterra, and were defeated only by '
#                      'cunning mortal sorcery. But after centuries of '
#                      'imprisonment, Aatrox was the first to find...',
#            'Ahri': 'Innately connected to the latent power of Runeterra, Ahri '
#                    'is a vastaya who can reshape magic into orbs of raw '
#                    'energy. She revels in toying with her prey by manipulating '
#                    'their emotions before devouring their life essence. '
#                    'Despite her predatory nature...',
#            'Akali': 'Abandoning the Kinkou Order and her title of the Fist of '
#                     'Shadow, Akali now strikes alone, ready to be the deadly '
# ...

# %%
Pandas=pd.DataFrame.from_dict(new_data)
Pandas
# Out:
#          version       id  key     name                   title  \
# Aatrox   12.15.1   Aatrox  266   Aatrox        the Darkin Blade
# Ahri     12.15.1     Ahri  103     Ahri     the Nine-Tailed Fox
# Akali    12.15.1    Akali   84    Akali      the Rogue Assassin
# Akshan   12.15.1   Akshan  166   Akshan      the Rogue Sentinel
# Alistar  12.15.1  Alistar   12  Alistar            the Minotaur
# ...          ...      ...  ...      ...                     ...
# Zeri     12.15.1     Zeri  221     Zeri       The Spark of Zaun
# Ziggs    12.15.1    Ziggs  115    Ziggs  the Hexplosives Expert
# Zilean   12.15.1   Zilean   26   Zilean        the Chronokeeper
# Zoe      12.15.1      Zoe  142      Zoe  the Aspect of Twilight
# Zyra     12.15.1     Zyra  143     Zyra      Rise of the Thorns
#
#                                                      blurb  \
# Aatrox   Once honored defenders of Shurima against the ...
# Ahri     Innately connected to the latent power of Rune...
# ...

# %%
IN = Pandas["info"]
IN
# Out:
# Aatrox     {'attack': 8, 'defense': 4, 'magic': 3, 'diffi...
# Ahri       {'attack': 3, 'defense': 4, 'magic': 8, 'diffi...
# Akali      {'attack': 5, 'defense': 3, 'magic': 8, 'diffi...
# Akshan     {'attack': 0, 'defense': 0, 'magic': 0, 'diffi...
# Alistar    {'attack': 6, 'defense': 9, 'magic': 5, 'diffi...
#                                  ...
# Zeri       {'attack': 8, 'defense': 5, 'magic': 3, 'diffi...
# Ziggs      {'attack': 2, 'defense': 4, 'magic': 9, 'diffi...
# Zilean     {'attack': 2, 'defense': 5, 'magic': 8, 'diffi...
# Zoe        {'attack': 1, 'defense': 7, 'magic': 8, 'diffi...
# Zyra       {'attack': 4, 'defense': 3, 'magic': 8, 'diffi...
# Name: info, Length: 161, dtype: object

# %%
info=pd.DataFrame.from_dict(IN)
info
# Out:
#                                                       info
# Aatrox   {'attack': 8, 'defense': 4, 'magic': 3, 'diffi...
# Ahri     {'attack': 3, 'defense': 4, 'magic': 8, 'diffi...
# Akali    {'attack': 5, 'defense': 3, 'magic': 8, 'diffi...
# Akshan   {'attack': 0, 'defense': 0, 'magic': 0, 'diffi...
# Alistar  {'attack': 6, 'defense': 9, 'magic': 5, 'diffi...
# ...                                                    ...
# Zeri     {'attack': 8, 'defense': 5, 'magic': 3, 'diffi...
# Ziggs    {'attack': 2, 'defense': 4, 'magic': 9, 'diffi...
# Zilean   {'attack': 2, 'defense': 5, 'magic': 8, 'diffi...
# Zoe      {'attack': 1, 'defense': 7, 'magic': 8, 'diffi...
# Zyra     {'attack': 4, 'defense': 3, 'magic': 8, 'diffi...
#
# [161 rows x 1 columns]

# %%
# Out:
#                                                      stats
# Aatrox   {'hp': 650, 'hpperlevel': 114, 'mp': 0, 'mpper...
# Ahri     {'hp': 570, 'hpperlevel': 96, 'mp': 418, 'mppe...
# Akali    {'hp': 570, 'hpperlevel': 119, 'mp': 200, 'mpp...
# Akshan   {'hp': 630, 'hpperlevel': 104, 'mp': 350, 'mpp...
# Alistar  {'hp': 670, 'hpperlevel': 120, 'mp': 350, 'mpp...
# ...                                                    ...
# Zeri     {'hp': 600, 'hpperlevel': 109, 'mp': 250, 'mpp...
# Ziggs    {'hp': 606, 'hpperlevel': 106, 'mp': 480, 'mpp...
# Zilean   {'hp': 574, 'hpperlevel': 96, 'mp': 452, 'mppe...
# Zoe      {'hp': 630, 'hpperlevel': 106, 'mp': 425, 'mpp...
# Zyra     {'hp': 574, 'hpperlevel': 93, 'mp': 418, 'mppe...
#
# [161 rows x 1 columns]

# %%
# Out:
#     level_0       id     hp  hpperlevel     mp  mpperlevel  movespeed  armor  \
# 0     stats   Aatrox  650.0         114    0.0         0.0        345     38
# 1     stats     Ahri  570.0          96  418.0        25.0        330     18
# 2     stats    Akali  570.0         119  200.0         0.0        345     23
# 3     stats   Akshan  630.0         104  350.0        40.0        330     26
# 4     stats  Alistar  670.0         120  350.0        40.0        330     44
# ..      ...      ...    ...         ...    ...         ...        ...    ...
# 156   stats     Zeri  600.0         109  250.0        45.0        325     20
# 157   stats    Ziggs  606.0         106  480.0        23.5        325     22
# 158   stats   Zilean  574.0          96  452.0        50.0        335     24
# 159   stats      Zoe  630.0         106  425.0        25.0        340     21
# 160   stats     Zyra  574.0          93  418.0        25.0        340     29
#
# ...

# %%
ADMD = REDO.rename(columns={'level_1': 'id'})
ADMD
# Out:
#     level_0       id  attack  defense  magic  difficulty
# 0      info   Aatrox       8        4      3           4
# 1      info     Ahri       3        4      8           5
# 2      info    Akali       5        3      8           7
# 3      info   Akshan       0        0      0           0
# 4      info  Alistar       6        9      5           7
# ..      ...      ...     ...      ...    ...         ...
# 156    info     Zeri       8        5      3           6
# 157    info    Ziggs       2        4      9           4
# 158    info   Zilean       2        5      8           6
# 159    info      Zoe       1        7      8           5
# 160    info     Zyra       4        3      8           7
#
# [161 rows x 6 columns]

# %%
merged_df = Pandas.merge(ADMD,on='id')

merged_df
# Out:
#      version       id  key     name                   title  \
# 0    12.15.1   Aatrox  266   Aatrox        the Darkin Blade
# 1    12.15.1     Ahri  103     Ahri     the Nine-Tailed Fox
# 2    12.15.1    Akali   84    Akali      the Rogue Assassin
# 3    12.15.1   Akshan  166   Akshan      the Rogue Sentinel
# 4    12.15.1  Alistar   12  Alistar            the Minotaur
# ..       ...      ...  ...      ...                     ...
# 156  12.15.1     Zeri  221     Zeri       The Spark of Zaun
# 157  12.15.1    Ziggs  115    Ziggs  the Hexplosives Expert
# 158  12.15.1   Zilean   26   Zilean        the Chronokeeper
# 159  12.15.1      Zoe  142      Zoe  the Aspect of Twilight
# 160  12.15.1     Zyra  143     Zyra      Rise of the Thorns
#
#                                                  blurb  \
# 0    Once honored defenders of Shurima against the ...
# 1    Innately connected to the latent power of Rune...
# 2    Abandoning the Kinkou Order and her title of t...
# ...

# %%
Pa=pd.DataFrame.from_dict(new_data1)
Pa
# Out:
#                                                  Aatrox  \
# info  {'attack': 8, 'defense': 4, 'magic': 3, 'diffi...
#
#                                                    Ahri  \
# info  {'attack': 3, 'defense': 4, 'magic': 8, 'diffi...
#
#                                                   Akali  \
# info  {'attack': 5, 'defense': 3, 'magic': 8, 'diffi...
#
#                                                  Akshan  \
# info  {'attack': 0, 'defense': 0, 'magic': 0, 'diffi...
#
#                                                 Alistar  \
# info  {'attack': 6, 'defense': 9, 'magic': 5, 'diffi...
#
#                                                   Amumu  \
# info  {'attack': 2, 'defense': 6, 'magic': 8, 'diffi...
#
#                                                  Anivia  \
# info  {'attack': 1, 'defense': 4, 'magic': 10, 'diff...
#
#                                                   Annie  \
# info  {'attack': 2, 'defense': 3, 'magic': 10, 'diff...
#
# ...

# %%
stat = Pandas["stats"]
Pan=pd.DataFrame.from_dict(stat)
Pan
# Out:
#                                                      stats
# Aatrox   {'hp': 650, 'hpperlevel': 114, 'mp': 0, 'mpper...
# Ahri     {'hp': 570, 'hpperlevel': 96, 'mp': 418, 'mppe...
# Akali    {'hp': 570, 'hpperlevel': 119, 'mp': 200, 'mpp...
# Akshan   {'hp': 630, 'hpperlevel': 104, 'mp': 350, 'mpp...
# Alistar  {'hp': 670, 'hpperlevel': 120, 'mp': 350, 'mpp...
# ...                                                    ...
# Zeri     {'hp': 600, 'hpperlevel': 109, 'mp': 250, 'mpp...
# Ziggs    {'hp': 606, 'hpperlevel': 106, 'mp': 480, 'mpp...
# Zilean   {'hp': 574, 'hpperlevel': 96, 'mp': 452, 'mppe...
# Zoe      {'hp': 630, 'hpperlevel': 106, 'mp': 425, 'mpp...
# Zyra     {'hp': 574, 'hpperlevel': 93, 'mp': 418, 'mppe...
#
# [161 rows x 1 columns]

# %%
ST=pd.DataFrame.from_dict({(i,j): Pan[i][j] 
                           for i in Pan.keys() 
                           for j in Pan[i].keys()},
                       orient='index')
ST.reset_index(inplace=True)
STATS = ST.rename(columns={'level_1': 'id'})
STATS
# Out:
#     level_0       id     hp  hpperlevel     mp  mpperlevel  movespeed  armor  \
# 0     stats   Aatrox  650.0         114    0.0         0.0        345     38
# 1     stats     Ahri  570.0          96  418.0        25.0        330     18
# 2     stats    Akali  570.0         119  200.0         0.0        345     23
# 3     stats   Akshan  630.0         104  350.0        40.0        330     26
# 4     stats  Alistar  670.0         120  350.0        40.0        330     44
# ..      ...      ...    ...         ...    ...         ...        ...    ...
# 156   stats     Zeri  600.0         109  250.0        45.0        325     20
# 157   stats    Ziggs  606.0         106  480.0        23.5        325     22
# 158   stats   Zilean  574.0          96  452.0        50.0        335     24
# 159   stats      Zoe  630.0         106  425.0        25.0        340     21
# 160   stats     Zyra  574.0          93  418.0        25.0        340     29
#
# ...

# %%
merged_df2 = Pandas.merge(STATS,on='id')

merged_df2
# Out:
#      version       id  key     name                   title  \
# 0    12.15.1   Aatrox  266   Aatrox        the Darkin Blade
# 1    12.15.1     Ahri  103     Ahri     the Nine-Tailed Fox
# 2    12.15.1    Akali   84    Akali      the Rogue Assassin
# 3    12.15.1   Akshan  166   Akshan      the Rogue Sentinel
# 4    12.15.1  Alistar   12  Alistar            the Minotaur
# ..       ...      ...  ...      ...                     ...
# 156  12.15.1     Zeri  221     Zeri       The Spark of Zaun
# 157  12.15.1    Ziggs  115    Ziggs  the Hexplosives Expert
# 158  12.15.1   Zilean   26   Zilean        the Chronokeeper
# 159  12.15.1      Zoe  142      Zoe  the Aspect of Twilight
# 160  12.15.1     Zyra  143     Zyra      Rise of the Thorns
#
#                                                  blurb  \
# 0    Once honored defenders of Shurima against the ...
# 1    Innately connected to the latent power of Rune...
# 2    Abandoning the Kinkou Order and her title of t...
# ...

# %%
df_clean = merged_df2.drop(columns=['info','stats','image'])
df_clean
# Out:
#      version       id  key     name                   title  \
# 0    12.15.1   Aatrox  266   Aatrox        the Darkin Blade
# 1    12.15.1     Ahri  103     Ahri     the Nine-Tailed Fox
# 2    12.15.1    Akali   84    Akali      the Rogue Assassin
# 3    12.15.1   Akshan  166   Akshan      the Rogue Sentinel
# 4    12.15.1  Alistar   12  Alistar            the Minotaur
# ..       ...      ...  ...      ...                     ...
# 156  12.15.1     Zeri  221     Zeri       The Spark of Zaun
# 157  12.15.1    Ziggs  115    Ziggs  the Hexplosives Expert
# 158  12.15.1   Zilean   26   Zilean        the Chronokeeper
# 159  12.15.1      Zoe  142      Zoe  the Aspect of Twilight
# 160  12.15.1     Zyra  143     Zyra      Rise of the Thorns
#
#                                                  blurb                  tags  \
# 0    Once honored defenders of Shurima against the ...       [Fighter, Tank]
# 1    Innately connected to the latent power of Rune...      [Mage, Assassin]
# ...

# %%
filepath = Path('/Users/adriennezane/Desktop/Data Bootcamp/game-analysis/Resources/Json_File.csv')
df_clean.to_csv(filepath)
