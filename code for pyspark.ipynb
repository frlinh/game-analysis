# %%
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import session
from sqlalchemy import create_engine, func
import psycopg2
import boto3
import findspark
import os
import pyspark
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/zq/5hj2yhf93p9c240d6_70k0s80000gn/T/ipykernel_41124/2142253549.py in <module>
#       7 import findspark
#       8 import os
# ----> 9 import pyspark
#
# ModuleNotFoundError: No module named 'pyspark'

# %%
from pyspark.sql import SparkSession
db_string = "postgres://admin:Ladybug0@gameanalysis.cjhwxnjx5697.us-west-1.rds.amazonaws.com"
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/zq/5hj2yhf93p9c240d6_70k0s80000gn/T/ipykernel_41124/1503777255.py in <module>
# ----> 1 from pyspark.sql import SparkSession
#       2 db_string = "postgres://admin:Ladybug0@gameanalysis.cjhwxnjx5697.us-west-1.rds.amazonaws.com"
#
# ModuleNotFoundError: No module named 'pyspark'

# %%
host= "gameanalysis.cjhwxnjx5697.us-west-1.rds.amazonaws.com"
port = "5432"
user= "postgres"
password= "5}eN^2g0rac3"
nombre_db= "gameanalysis"
url= "postgresql://{user}:{password}@{host}/{nombre_db}"

# %%
host
# Out:
# 'gameanalysis.cjhwxnjx5697.us-west-1.rds.amazonaws.com'

# %%
try:
     conn = psycopg2.connect(database=nombre_db,
                            user=user,
                            password=password,
                            host=host,
                            port=port)
     print("Database connected successfully")
except:
     print("Database not connected successfully")
# Out:
# Database not connected successfully

# %%
engine = create_engine(url)
conn = engine.connect()
conn
Base = automap_base()
Base.prepare(engine, refelect=True)
Measurement = Base.classes.Measurement
Station = Base.classes.station
session = session(engine)
white_check_mark
eyes
raised_hands
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    3279         try:
# -> 3280             return fn()
#    3281         except dialect.dbapi.Error as e:
#
# ~/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sqlalchemy/pool/base.py in connect(self)
#     309         """
# --> 310         return _ConnectionFairy._checkout(self)
#     311
#
# ~/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sqlalchemy/pool/base.py in _checkout(cls, pool, threadconns, fairy)
#     867         if not fairy:
# --> 868             fairy = _ConnectionRecord.checkout(pool)
#     869
#
# ~/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sqlalchemy/pool/base.py in checkout(cls, pool)
#     475     def checkout(cls, pool):
# --> 476         rec = pool._do_get()
# ...
