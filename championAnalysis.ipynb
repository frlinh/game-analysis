# %%
# Import Dependencies
import pandas as pd
import numpy as np
import psycopg2
from psycopg2 import sql

# %%
# AWS RDS Connection
PGEND_POINT = 'gameanalysis.cjhwxnjx5697.us-west-1.rds.amazonaws.com' # End_point
PGDATABASE_NAME = 'gameanalysis' # Database Name example: youtube_test_db
PGUSER_NAME = 'postgres' # UserName

# %%
# Connect to AWS RDS
def connect():
    
    # Set up a connection to the postgres server.
    conn_string = "host="+ PGEND_POINT +" port="+ "5432" +" user=" + PGUSER_NAME \
                  +" password="+ PGPASSWORD
    
    conn = psycopg2.connect(conn_string)
    print("Connected!")

    # Create a cursor object
    cursor = conn.cursor()
    
    return conn, cursor

# %%
#Check Connection
conn, cursor = connect()
# Out:
# Connected!

# %% [markdown]
# CHAMPIONS MASTERY

# %%
# Select champion mastery table
query_championMastery = sql.SQL("""
SELECT * FROM "championMastery";
""")

# %%
cur = conn.cursor()
cur.execute(query_championMastery)

# %%
df_championMastery = pd.DataFrame(cur.fetchall(), columns=[
    'summonerId', 'championId', 'championLevel', 'championPoints', 'lastPlayTime'
    , 'championPointsSinceLastLevel', 'championPointsUntilNextLevel', 'tokensEarned'])

# %%
# Drop null values
df_championMastery.dropna()
# Out:
#                                              summonerId championId  \
# 0       HrertYKBrFGl4VtH1QmDWc6HeINPXkbO1OOUL7boXVoaybU         37
# 1       HrertYKBrFGl4VtH1QmDWc6HeINPXkbO1OOUL7boXVoaybU         99
# 2       HrertYKBrFGl4VtH1QmDWc6HeINPXkbO1OOUL7boXVoaybU         40
# 3       HrertYKBrFGl4VtH1QmDWc6HeINPXkbO1OOUL7boXVoaybU        267
# 4       HrertYKBrFGl4VtH1QmDWc6HeINPXkbO1OOUL7boXVoaybU         16
# ...                                                 ...        ...
# 531567  zYfi7jIcNjvMvTWgF8GLs951w5M6k9zEv1agNSne_OOY-oc        497
# 531568  zYfi7jIcNjvMvTWgF8GLs951w5M6k9zEv1agNSne_OOY-oc         89
# 531569  zYfi7jIcNjvMvTWgF8GLs951w5M6k9zEv1agNSne_OOY-oc         32
# 531570  zYfi7jIcNjvMvTWgF8GLs951w5M6k9zEv1agNSne_OOY-oc        161
# 531571  zYfi7jIcNjvMvTWgF8GLs951w5M6k9zEv1agNSne_OOY-oc         56
#
#         championLevel  championPoints  lastPlayTime  \
# 0                   7          602952  1.658697e+12
# 1                   7           87340  1.657737e+12
# 2                   7           85539  1.654451e+12
# 3                   5           82364  1.659732e+12
# 4                   7           77550  1.661647e+12
# ...               ...             ...           ...
# 531567              1             152  1.613491e+12
# 531568              1             150  1.601873e+12
# 531569              1             145  1.549192e+12
# 531570              1             134  1.602209e+12
# 531571              1             122  1.627237e+12
#
#         championPointsSinceLastLevel  championPointsUntilNextLevel  \
# 0                             581352                             0
# 1                              65740                             0
# 2                              63939                             0
# 3                              60764                             0
# 4                              55950                             0
# ...                              ...                           ...
# 531567                           152                          1648
# 531568                           150                          1650
# 531569                           145                          1655
# 531570                           134                          1666
# 531571                           122                          1678
#
#         tokensEarned
# 0                  0
# 1                  0
# 2                  0
# 3                  2
# 4                  0
# ...              ...
# 531567             0
# 531568             0
# 531569             0
# 531570             0
# 531571             0
#
# [531572 rows x 8 columns]

# %%
# Get count of unique summoners
summoner_count = len(df_championMastery["summonerId"].unique())
summoner_count
# Out:
# 4418

# %%
# avg and sum of champion points by Champion
avgChampionPoints = df_championMastery.groupby(["championId"]).mean()["championPoints"]
totalChampionPoints = df_championMastery.groupby(["championId"]).sum()["championPoints"]
# count of summons by Champion
countOfSummons = df_championMastery.groupby(["championId"]).count()["summonerId"]

# %%
champions_summary_df = pd.DataFrame({
    "Avg Champion Points per Summon": avgChampionPoints.map("{:,.0f}".format),
    "Total Number of Points": totalChampionPoints.map("{:,.0f}".format),
    "Total Number of Summons": countOfSummons.map("{:,.0f}".format)
})

champions_summary_df.head()
# Out:
#            Avg Champion Points per Summon Total Number of Points  \
# championId
# 1                                  19,468             70,006,450
# 10                                 16,753             62,319,329
# 101                                19,605             64,990,052
# 102                                13,595             43,163,917
# 103                                39,749            146,196,403
#
#            Total Number of Summons
# championId
# 1                            3,596
# 10                           3,720
# 101                          3,315
# 102                          3,175
# 103                          3,678

# %%
print(champions_summary_df.dtypes)
# Out:
# Avg Champion Points per Summon    object
# Total Number of Points            object
# Total Number of Summons           object
# dtype: object

# %%
sorted_champions_summary_df_summons = champions_summary_df.sort_values(by='Total Number of Summons', ascending=False)
sorted_champions_summary_df_summons
# Out:
#            Avg Champion Points per Summon Total Number of Points  \
# championId
# 81                                 71,418            291,242,515
# 22                                 33,043            134,286,298
# 236                                65,317            261,988,482
# 104                                47,561            188,152,234
# 67                                 67,067            263,102,216
# ...                                   ...                    ...
# 83                                  9,154             21,163,063
# 888                                 8,250             15,558,576
# 526                                 8,568             14,874,106
# 200                                 3,528              5,345,217
# 895                                 2,429              3,507,404
#
#            Total Number of Summons
# championId
# 81                           4,078
# 22                           4,064
# 236                          4,011
# 104                          3,956
# 67                           3,923
# ...                            ...
# 83                           2,312
# 888                          1,886
# 526                          1,736
# 200                          1,515
# 895                          1,444
#
# [161 rows x 3 columns]

# %%
sorted_champions_summary_df_championPoints = champions_summary_df.sort_values(by='Total Number of Points', ascending=False)
sorted_champions_summary_df_championPoints
# Out:
#            Avg Champion Points per Summon Total Number of Points  \
# championId
# 79                                 28,452             98,982,991
# 61                                 29,097             97,097,813
# 76                                 26,611             96,038,791
# 16                                 25,659             94,911,555
# 432                                30,080             94,720,442
# ...                                   ...                    ...
# 105                                31,803            111,500,406
# 267                                36,229            107,129,369
# 498                                29,824            106,352,249
# 11                                 28,439            105,877,454
# 25                                 27,812            102,542,876
#
#            Total Number of Summons
# championId
# 79                           3,479
# 61                           3,337
# 76                           3,609
# 16                           3,699
# 432                          3,149
# ...                            ...
# 105                          3,506
# 267                          2,957
# 498                          3,566
# 11                           3,723
# 25                           3,687
#
# [161 rows x 3 columns]

# %%
highestAvgChampionPoints = sorted_champions_summary_df_championPoints.loc[sorted_champions_summary_df_championPoints['Avg Champion Points per Summon'] > '65000']
highestAvgChampionPoints
# Out:
#            Avg Champion Points per Summon Total Number of Points  \
# championId
# 157                                94,557            349,481,115
# 81                                 71,418            291,242,515
# 64                                 71,916            280,042,757
# 887                                 9,574             27,210,635
# 67                                 67,067            263,102,216
# 202                                67,058            259,648,006
# 166                                 9,776             25,094,107
# 412                                66,116            240,727,871
# 83                                  9,154             21,163,063
# 711                                 7,416             18,858,040
# 888                                 8,250             15,558,576
# 526                                 8,568             14,874,106
#
#            Total Number of Summons
# championId
# 157                          3,696
# 81                           4,078
# 64                           3,894
# 887                          2,842
# 67                           3,923
# 202                          3,872
# 166                          2,567
# 412                          3,641
# 83                           2,312
# 711                          2,543
# 888                          1,886
# 526                          1,736

# %%
sorted_highestAvgChampionPoints = highestAvgChampionPoints.sort_values(by='Avg Champion Points per Summon', ascending=False)
sorted_highestAvgChampionPoints
# Out:
#            Avg Champion Points per Summon Total Number of Points  \
# championId
# 157                                94,557            349,481,115
# 166                                 9,776             25,094,107
# 887                                 9,574             27,210,635
# 83                                  9,154             21,163,063
# 526                                 8,568             14,874,106
# 888                                 8,250             15,558,576
# 64                                 71,916            280,042,757
# 81                                 71,418            291,242,515
# 711                                 7,416             18,858,040
# 67                                 67,067            263,102,216
# 202                                67,058            259,648,006
# 412                                66,116            240,727,871
#
#            Total Number of Summons
# championId
# 157                          3,696
# 166                          2,567
# 887                          2,842
# 83                           2,312
# 526                          1,736
# 888                          1,886
# 64                           3,894
# 81                           4,078
# 711                          2,543
# 67                           3,923
# 202                          3,872
# 412                          3,641

# %%
sorted_champions_summary_df_avgpersummons = champions_summary_df.sort_values(by='Avg Champion Points per Summon', ascending=False)
sorted_champions_summary_df_avgpersummons.head()
# Out:
#            Avg Champion Points per Summon Total Number of Points  \
# championId
# 157                                94,557            349,481,115
# 166                                 9,776             25,094,107
# 887                                 9,574             27,210,635
# 83                                  9,154             21,163,063
# 526                                 8,568             14,874,106
#
#            Total Number of Summons
# championId
# 157                          3,696
# 166                          2,567
# 887                          2,842
# 83                           2,312
# 526                          1,736

# %%
# champion157 = champions_difficulty_df[(champions_difficulty_df['Champion Id'] == 157)]
# champion157

# %%
# champion64 = champions_difficulty_df[(champions_difficulty_df['Champion Id'] == 64)]
# champion64

# %%
# champion81 = champions_difficulty_df[(champions_difficulty_df['Champion Id'] == 81)]
# champion81

# %%
# Select champions table
query_champions = sql.SQL("""
SELECT * FROM champions;
""")

# %%
# connect to table
cur = conn.cursor()
cur.execute(query_champions)

# %%
# Test print one row
print(cur.fetchone())
# Out:
# ('Annie', 1, 2, 3, 10, 6, 'Mage', 'n/a', 524.0, 88.0, 418.0, 25.0, 335, 19.22, 4.0, 30.0, 0.5, 625, 5.5, 0.55, 8.0, 0.8, 0, 0, 50.41, 2.625, 1.36, 0.579)

# %%
# Test print all rows
cur = conn.cursor()
cur.execute(query_champions)
print(cur.fetchall())
# Out:
# [('Annie', 1, 2, 3, 10, 6, 'Mage', 'n/a', 524.0, 88.0, 418.0, 25.0, 335, 19.22, 4.0, 30.0, 0.5, 625, 5.5, 0.55, 8.0, 0.8, 0, 0, 50.41, 2.625, 1.36, 0.579), ('Olaf', 2, 9, 5, 3, 3, 'Fighter', 'Tank', 597.24, 93.0, 315.6, 42.0, 350, 35.0, 3.0, 32.1, 1.25, 125, 8.5, 0.9, 7.466, 0.575, 0, 0, 68.0, 3.5, 2.7, 0.694), ('Galio', 3, 1, 10, 6, 5, 'Tank', 'Mage', 562.0, 112.0, 500.0, 40.0, 335, 24.0, 3.5, 32.0, 1.25, 150, 8.0, 0.8, 9.5, 0.7, 0, 0, 59.0, 3.5, 1.5, 0.625), ('TwistedFate', 4, 6, 2, 6, 9, 'Mage', 'n/a', 534.0, 94.0, 333.0, 19.0, 335, 21.0, 3.15, 30.0, 0.5, 525, 5.5, 0.6, 8.0, 0.8, 0, 0, 52.0, 3.3, 3.22, 0.651), ('XinZhao', 5, 8, 6, 3, 2, 'Fighter', 'Assassin', 570.0, 92.0, 273.8, 35.0, 345, 35.0, 3.5, 32.1, 1.25, 175, 8.0, 0.7, 7.256, 0.45, 0, 0, 66.0, 3.0, 3.5, 0.645), ('Urgot', 6, 8, 5, 3, 8, 'Fighter', 'Tank', 585.0, 88.0, 340.0, 45.0, 330, 36.0, 4.25, 32.1, 1.25, 350, 7.5, 0.7, 7.25, 0.8, 0, 0, 63.0, 4.0, 3.75, 0.625), ('Leblanc', 7, 1, 4, 10, 9, 'Assassin', 'Mage', 528.0, 92.0, 334.0, 50.0, 340, 21.88, 3.5, 30.0, 0.5, 525, 7.5, 0.55, 6.0, 0.8, 0, 0, 54.88, 3.5, 1.4, 0.625), ('Vladimir', 8, 2, 6, 8, 7, 'Mage', 'n/a', 537.0, 96.0, 2.0, 0.0, 330, 23.0, 3.3, 30.0, 0.5, 450, 7.0, 0.6, 0.0, 0.0, 0, 0, 55.0, 3.0, 2.0, 0.658), ('Fiddlesticks', 9, 2, 3, 9, 9, 'Mage', 'Support', 580.4, 92.0, 500.0, 28.0, 335, 34.0, 3.5, 30.0, 0.5, 480, 5.5, 0.6, 8.0, 0.8, 0, 0, 55.36, 2.625, 2.11, 0.625), ('Kayle', 10, 6, 6, 7, 7, 'Fighter', 'Support', 600.0, 85.0, 330.0, 50.0, 335, 26.0, 3.0, 34.0, 0.5, 175, 5.0, 0.5, 8.0, 0.8, 0, 0, 50.0, 2.5, 1.5, 0.625), ('MasterYi', 11, 10, 4, 2, 4, 'Assassin', 'Fighter', 598.56, 92.0, 250.56, 42.0, 355, 33.0, 3.0, 32.1, 1.25, 125, 7.5, 0.65, 7.256, 0.45, 0, 0, 66.0, 3.0, 2.0, 0.679), ('Alistar', 12, 6, 9, 5, 7, 'Tank', 'Support', 600.0, 106.0, 350.0, 40.0, 330, 44.0, 3.5, 32.1, 1.25, 125, 8.5, 0.85, 8.5, 0.8, 0, 0, 62.0, 3.75, 2.125, 0.625), ('Ryze', 13, 2, 2, 10, 7, 'Mage', 'Fighter', 575.0, 98.0, 300.0, 50.0, 340, 22.0, 3.0, 36.0, 0.5, 550, 8.0, 0.8, 8.0, 1.0, 0, 0, 58.0, 3.0, 2.112, 0.625), ('Sion', 14, 5, 9, 3, 5, 'Tank', 'Fighter', 545.0, 73.0, 330.0, 42.0, 345, 32.0, 3.0, 32.1, 1.25, 175, 7.5, 0.8, 8.0, 0.6, 0, 0, 68.0, 4.0, 1.3, 0.679), ('Sivir', 15, 9, 3, 1, 4, 'Marksman', 'Marksman', 562.0, 90.0, 284.0, 50.0, 335, 26.0, 3.25, 30.0, 0.5, 500, 3.25, 0.55, 8.0, 0.9, 0, 0, 63.0, 3.0, 1.6, 0.625), ('Soraka', 16, 2, 5, 7, 3, 'Support', 'Mage', 535.0, 74.0, 425.0, 40.0, 325, 32.0, 3.8, 30.0, 0.5, 550, 2.5, 0.5, 11.5, 0.4, 0, 0, 50.0, 3.0, 2.14, 0.625), ('Teemo', 17, 5, 3, 7, 6, 'Marksman', 'Assassin', 528.0, 90.0, 334.0, 20.0, 330, 24.3, 3.75, 30.0, 0.5, 500, 5.5, 0.65, 9.6, 0.45, 0, 0, 54.0, 3.0, 3.38, 0.69), ('Tristana', 18, 9, 3, 5, 4, 'Marksman', 'Assassin', 559.0, 88.0, 250.0, 32.0, 325, 26.0, 3.0, 30.0, 0.5, 525, 3.75, 0.65, 7.2, 0.45, 0, 0, 61.0, 3.3, 1.5, 0.656), ('Warwick', 19, 9, 5, 3, 3, 'Fighter', 'Tank', 550.0, 85.0, 280.0, 35.0, 335, 33.0, 3.2, 32.1, 1.25, 125, 4.0, 0.75, 7.466, 0.575, 0, 0, 65.0, 3.0, 2.3, 0.638), ('Nunu', 20, 4, 6, 7, 4, 'Tank', 'Fighter', 570.0, 82.0, 280.0, 42.0, 345, 32.0, 3.0, 32.1, 1.25, 125, 5.0, 0.8, 7.0, 0.5, 0, 0, 61.0, 3.0, 2.25, 0.625), ('MissFortune', 21, 8, 2, 5, 1, 'Marksman', 'Marksman', 570.0, 93.0, 325.84, 35.0, 325, 28.0, 3.0, 30.0, 0.5, 550, 3.75, 0.65, 8.042, 0.65, 0, 0, 52.0, 2.7, 2.25, 0.656), ('Ashe', 22, 7, 3, 2, 4, 'Marksman', 'Mage', 570.0, 87.0, 280.0, 32.0, 325, 26.0, 3.4, 30.0, 0.5, 600, 3.5, 0.55, 6.972, 0.4, 0, 0, 61.0, 2.96, 3.33, 0.658), ('Tryndamere', 23, 10, 5, 2, 5, 'Fighter', 'Assassin', 625.64, 98.0, 100.0, 0.0, 345, 33.0, 3.1, 32.1, 1.25, 125, 8.5, 0.9, 0.0, 0.0, 0, 0, 69.0, 3.7, 2.9, 0.67), ('Jax', 24, 7, 5, 7, 5, 'Fighter', 'Assassin', 592.8, 85.0, 338.8, 32.0, 350, 36.0, 3.0, 32.1, 1.25, 125, 8.5, 0.55, 7.576, 0.7, 0, 0, 68.0, 3.375, 3.4, 0.638), ('Morgana', 25, 1, 6, 8, 1, 'Mage', 'Support', 560.0, 90.0, 340.0, 60.0, 335, 25.0, 3.8, 30.0, 0.5, 450, 5.5, 0.4, 11.0, 0.4, 0, 0, 56.0, 3.5, 1.53, 0.625), ('Zilean', 26, 2, 5, 8, 6, 'Sup ...

# %%
# Fetch two rows
cur = conn.cursor()
cur.execute(query_champions)
rows_to_fetch = 2
print(cur.fetchmany(rows_to_fetch))
# Out:
# [('Annie', 1, 2, 3, 10, 6, 'Mage', 'n/a', 524.0, 88.0, 418.0, 25.0, 335, 19.22, 4.0, 30.0, 0.5, 625, 5.5, 0.55, 8.0, 0.8, 0, 0, 50.41, 2.625, 1.36, 0.579), ('Olaf', 2, 9, 5, 3, 3, 'Fighter', 'Tank', 597.24, 93.0, 315.6, 42.0, 350, 35.0, 3.0, 32.1, 1.25, 125, 8.5, 0.9, 7.466, 0.575, 0, 0, 68.0, 3.5, 2.7, 0.694)]

# %%
#Build champions dataframe
df_champions = pd.DataFrame(cur.fetchall(), columns=[
    'id', 'key', 'attack', 'defense', 'magic'
	, 'difficulty', 'tag1', 'tag2', 'hp', 'hpperlevel'
  , 'mp', 'mpperlevel', 'movespeed', 'armor', 'armorperlevel'
  , 'spellblock', 'spellblockperlevel', 'attackrange', 'hpregen', 'hpregenperlevel'
  , 'mpregen', 'mpregenperlevel', 'crit', 'critperlevel'
  , 'attackdamage', 'attackdamageperlevel', 'attackspeedperlevel', 'attackspeed'])

# %%
#check dataFrame
df_champions
# Out:
#               id  key  attack  defense  magic  difficulty      tag1      tag2  \
# 0          Galio    3       1       10      6           5      Tank      Mage
# 1    TwistedFate    4       6        2      6           9      Mage       n/a
# 2        XinZhao    5       8        6      3           2   Fighter  Assassin
# 3          Urgot    6       8        5      3           8   Fighter      Tank
# 4        Leblanc    7       1        4     10           9  Assassin      Mage
# ..           ...  ...     ...      ...    ...         ...       ...       ...
# 143     Aphelios  523       6        2      1          10  Marksman  Marksman
# 144         Pyke  555       9        3      1           7   Support  Assassin
# 145         Yone  777       8        4      4           8  Assassin   Fighter
# 146         Sett  875       8        5      1           2   Fighter      Tank
# 147       Lillia  876       0        2     10           8   Fighter      Mage
#
#         hp  hpperlevel  ...  hpregen  hpregenperlevel  mpregen  \
# 0    562.0       112.0  ...     8.00             0.80    9.500
# 1    534.0        94.0  ...     5.50             0.60    8.000
# 2    570.0        92.0  ...     8.00             0.70    7.256
# 3    585.0        88.0  ...     7.50             0.70    7.250
# 4    528.0        92.0  ...     7.50             0.55    6.000
# ..     ...         ...  ...      ...              ...      ...
# 143  530.0        88.0  ...     3.25             0.55    6.500
# 144  600.0        90.0  ...     7.00             0.50    8.000
# 145  550.0        85.0  ...     7.50             0.75    0.000
# 146  600.0        93.0  ...     7.00             0.50    0.000
# 147  580.0        90.0  ...     9.00             0.75   11.500
#
#      mpregenperlevel  crit  critperlevel  attackdamage  attackdamageperlevel  \
# 0               0.70     0             0         59.00                   3.5
# 1               0.80     0             0         52.00                   3.3
# 2               0.45     0             0         66.00                   3.0
# 3               0.80     0             0         63.00                   4.0
# 4               0.80     0             0         54.88                   3.5
# ..               ...   ...           ...           ...                   ...
# 143             0.40     0             0         57.00                   2.0
# 144             1.00     0             0         62.00                   2.0
# 145             0.00     0             0         60.00                   3.0
# 146             0.00     0             0         60.00                   4.0
# 147             0.95     0             0         61.00                   3.1
#
#      attackspeedperlevel  attackspeed
# 0                   1.50        0.625
# 1                   3.22        0.651
# 2                   3.50        0.645
# 3                   3.75        0.625
# 4                   1.40        0.625
# ..                   ...          ...
# 143                 2.10        0.640
# 144                 2.50        0.667
# 145                 2.50        0.625
# 146                 1.75        0.625
# 147                 2.70        0.625
#
# [148 rows x 28 columns]

# %%
# Drop null values
df_champions.dropna()
# Out:
#               id  key  attack  defense  magic  difficulty      tag1      tag2  \
# 0          Galio    3       1       10      6           5      Tank      Mage
# 1    TwistedFate    4       6        2      6           9      Mage       n/a
# 2        XinZhao    5       8        6      3           2   Fighter  Assassin
# 3          Urgot    6       8        5      3           8   Fighter      Tank
# 4        Leblanc    7       1        4     10           9  Assassin      Mage
# ..           ...  ...     ...      ...    ...         ...       ...       ...
# 143     Aphelios  523       6        2      1          10  Marksman  Marksman
# 144         Pyke  555       9        3      1           7   Support  Assassin
# 145         Yone  777       8        4      4           8  Assassin   Fighter
# 146         Sett  875       8        5      1           2   Fighter      Tank
# 147       Lillia  876       0        2     10           8   Fighter      Mage
#
#         hp  hpperlevel  ...  hpregen  hpregenperlevel  mpregen  \
# 0    562.0       112.0  ...     8.00             0.80    9.500
# 1    534.0        94.0  ...     5.50             0.60    8.000
# 2    570.0        92.0  ...     8.00             0.70    7.256
# 3    585.0        88.0  ...     7.50             0.70    7.250
# 4    528.0        92.0  ...     7.50             0.55    6.000
# ..     ...         ...  ...      ...              ...      ...
# 143  530.0        88.0  ...     3.25             0.55    6.500
# 144  600.0        90.0  ...     7.00             0.50    8.000
# 145  550.0        85.0  ...     7.50             0.75    0.000
# 146  600.0        93.0  ...     7.00             0.50    0.000
# 147  580.0        90.0  ...     9.00             0.75   11.500
#
#      mpregenperlevel  crit  critperlevel  attackdamage  attackdamageperlevel  \
# 0               0.70     0             0         59.00                   3.5
# 1               0.80     0             0         52.00                   3.3
# 2               0.45     0             0         66.00                   3.0
# 3               0.80     0             0         63.00                   4.0
# 4               0.80     0             0         54.88                   3.5
# ..               ...   ...           ...           ...                   ...
# 143             0.40     0             0         57.00                   2.0
# 144             1.00     0             0         62.00                   2.0
# 145             0.00     0             0         60.00                   3.0
# 146             0.00     0             0         60.00                   4.0
# 147             0.95     0             0         61.00                   3.1
#
#      attackspeedperlevel  attackspeed
# 0                   1.50        0.625
# 1                   3.22        0.651
# 2                   3.50        0.645
# 3                   3.75        0.625
# 4                   1.40        0.625
# ..                   ...          ...
# 143                 2.10        0.640
# 144                 2.50        0.667
# 145                 2.50        0.625
# 146                 1.75        0.625
# 147                 2.70        0.625
#
# [148 rows x 28 columns]

# %%
# Print statistics
df_champions.describe()
# Out:
#               key      attack     defense       magic  difficulty          hp  \
# count  148.000000  148.000000  148.000000  148.000000  148.000000  148.000000
# mean   140.216216    5.466216    4.682432    5.378378    5.790541  558.009730
# std    163.968121    2.788254    2.093193    2.738999    2.097142   37.327847
# min      3.000000    0.000000    1.000000    1.000000    1.000000  340.000000
# 25%     39.750000    3.000000    3.000000    3.000000    4.000000  534.000000
# 50%     85.500000    6.000000    5.000000    6.000000    6.000000  565.000000
# 75%    151.000000    8.000000    6.000000    8.000000    7.000000  582.950000
# max    876.000000   10.000000   10.000000   10.000000   10.000000  625.640000
#
#        hpperlevel          mp  mpperlevel   movespeed  ...     hpregen  \
# count  148.000000  148.000000  148.000000  148.000000  ...  148.000000
# mean    88.993243  310.172027   32.864865  336.270270  ...    6.614865
# std      7.074431  119.220728   17.041725    7.507452  ...    1.798615
# min     65.000000    0.000000    0.000000  315.000000  ...    2.500000
# 25%     85.000000  280.000000   25.000000  330.000000  ...    5.500000
# 50%     90.000000  325.300000   40.000000  335.000000  ...    7.000000
# 75%     93.000000  375.000000   45.000000  340.000000  ...    8.000000
# max    115.000000  500.000000   67.000000  355.000000  ...   10.000000
#
#        hpregenperlevel     mpregen  mpregenperlevel   crit  critperlevel  \
# count       148.000000  148.000000       148.000000  148.0         148.0
# mean          0.665203    8.332358         0.549662    0.0           0.0
# std           0.160427    8.364865         0.289190    0.0           0.0
# min           0.400000    0.000000         0.000000    0.0           0.0
# 25%           0.550000    6.500000         0.400000    0.0           0.0
# 50%           0.600000    7.583000         0.600000    0.0           0.0
# 75%           0.750000    8.002500         0.800000    0.0           0.0
# max           1.750000   50.000000         1.000000    0.0           0.0
#
#        attackdamage  attackdamageperlevel  attackspeedperlevel  attackspeed
# count    148.000000            148.000000           148.000000   148.000000
# mean      59.470094              3.225315             2.473291     0.647081
# std        5.906604              0.645631             0.828711     0.034326
# min       40.368000              0.000000             0.000000     0.475000
# 25%       55.000000              3.000000             2.000000     0.625000
# 50%       60.000000              3.110000             2.500000     0.639000
# 75%       64.000000              3.500000             3.025000     0.658000
# max       70.000000              5.000000             6.000000     0.800000
#
# [8 rows x 25 columns]

# %%
# Calculate avg score for attack, defense, magic and difficulty scores
df_champion_element = df_champions[['id', 'attack', 'defense', 'magic', 'difficulty']]
df_champion_element['elementAvgScore'] = df_champion_element.mean(axis=1)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# Sort by average element score
sorted_df_champion_element = df_champion_element.sort_values(by='elementAvgScore', ascending=False)
sorted_df_champion_element
# Out:
#           id  attack  defense  magic  difficulty  elementAvgScore
# 59    Rumble       3        6      8          10             6.75
# 32     Shaco       8        4      6           9             6.75
# 9    Alistar       6        9      5           7             6.75
# 53     Elise       6        5      7           9             6.75
# 7      Kayle       6        6      7           7             6.50
# ..       ...     ...      ...    ...         ...              ...
# 118  Kindred       8        2      2           4             4.00
# 19      Ashe       7        3      2           4             4.00
# 22   Morgana       1        6      8           1             4.00
# 131    Yuumi       5        1      8           2             4.00
# 126   Qiyana       0        2      4           8             3.50
#
# [148 rows x 6 columns]

# %%
df_champion_stats = df_champions[['id', 'hp', 'mp', 'movespeed', 'armor', 'spellblock', 'attackrange', 'hpregen', 'mpregen', 'crit', 'attackdamage', 'attackspeed']]
df_champion_stats['statsAvgScore'] = df_champion_stats.mean(axis=1)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
sorted_df_champion_stats = df_champion_stats.sort_values(by='statsAvgScore', ascending=False)
sorted_df_champion_stats
# Out:
#                id      hp     mp  movespeed   armor  spellblock  attackrange  \
# 6    Fiddlesticks  580.40  500.0        335  34.000        30.0          480
# 101     Lissandra  550.00  475.0        325  22.000        30.0          550
# 31         Anivia  480.00  495.0        325  21.220        30.0          600
# 94          Ziggs  536.00  480.0        325  21.544        30.0          550
# 130          Azir  552.00  480.0        335  19.040        30.0          525
# ..            ...     ...    ...        ...     ...         ...          ...
# 146          Sett  600.00    0.0        340  33.000        32.0          125
# 48       Katarina  602.00    0.0        340  27.880        32.1          125
# 33        DrMundo  582.52    0.0        345  36.000        32.1          125
# 78          Riven  560.00    0.0        340  33.000        32.1          125
# 124          Kled  340.00  100.0        345  35.000        32.1          125
#
#      hpregen  mpregen  crit  attackdamage  attackspeed  statsAvgScore
# 6        5.5      8.0     0        55.360        0.625     184.444091
# 101      7.0      8.0     0        53.000        0.656     183.696000
# 31       5.5      8.0     0        51.376        0.625     183.338273
# 94       6.5      8.0     0        54.208        0.656     182.900727
# 130      7.0      8.0     0        52.000        0.625     182.605909
# ..       ...      ...   ...           ...          ...            ...
# 146      7.0      0.0     0        60.000        0.625     108.875000
# 48       7.5      0.0     0        58.000        0.658     108.467091
# 33       8.0      0.0     0        61.270        0.721     108.237364
# 78       8.5      0.0     0        64.000        0.625     105.747727
# 124      6.0      0.0     0        65.000        0.625      95.338636
#
# [148 rows x 13 columns]

# %%
df_champion_statsperLevel = df_champions[['id', 'hpperlevel', 'mpperlevel', 'armorperlevel','spellblockperlevel', 'hpregenperlevel', 'mpregenperlevel', 'critperlevel', 'attackdamageperlevel', 'attackspeedperlevel']]
df_champion_statsperLevel['statsperLevelAvgScore'] = df_champion_statsperLevel.mean(axis=1)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
sorted_df_champion_statsperLevel = df_champion_statsperLevel.sort_values(by='statsperLevelAvgScore', ascending=False)
sorted_df_champion_statsperLevel
# Out:
#            id  hpperlevel  mpperlevel  armorperlevel  spellblockperlevel  \
# 141     Sylas       115.0        50.0           4.00                1.75
# 35   Kassadin        90.0        67.0           2.80                0.50
# 135     Ivern        95.0        60.0           3.50                1.25
# 0       Galio       112.0        40.0           3.50                1.25
# 22    Morgana        90.0        60.0           3.80                0.50
# ..        ...         ...         ...            ...                 ...
# 145      Yone        85.0         0.0           3.40                1.25
# 134    RekSai        85.0         0.0           3.75                1.25
# 59     Rumble        85.0         0.0           3.50                1.25
# 124      Kled        70.0         0.0           4.00                1.25
# 110      Gnar        65.0         0.0           2.50                0.50
#
#      hpregenperlevel  mpregenperlevel  critperlevel  attackdamageperlevel  \
# 141             0.90             0.80             0                   3.0
# 35              0.50             0.80             0                   3.9
# 135             0.85             0.75             0                   3.0
# 0               0.80             0.70             0                   3.5
# 22              0.40             0.40             0                   3.5
# ..               ...              ...           ...                   ...
# 145             0.75             0.00             0                   3.0
# 134             0.65             0.00             0                   3.0
# 59              0.60             0.00             0                   3.2
# 124             0.75             0.00             0                   3.5
# 110             1.75             0.00             0                   3.0
#
#      attackspeedperlevel  statsperLevelAvgScore
# 141                 3.50              19.883333
# 35                  3.70              18.800000
# 135                 3.40              18.638889
# 0                   1.50              18.138889
# 22                  1.53              17.792222
# ..                   ...                    ...
# 145                 2.50              10.655556
# 134                 2.00              10.627778
# 59                  1.85              10.600000
# 124                 3.50               9.222222
# 110                 6.00               8.750000
#
# [148 rows x 11 columns]

# %%
# Define new column names
championName = sorted_df_champion_element['id']
difficulty = sorted_df_champion_element['difficulty']
elementAvg = sorted_df_champion_element['elementAvgScore']
statsAvg = sorted_df_champion_stats['statsAvgScore']
statsPerLevelAvg = sorted_df_champion_statsperLevel['statsperLevelAvgScore']

# %%
# Create new data frame
new_champions_df = pd.DataFrame({
    "Champion Name": championName,
    "Difficulty": difficulty,
    "Avg Element Score": elementAvg,
    "Avg Stats Score": statsAvg,
    "Avg Stats per Level Score": statsPerLevelAvg
})

# %%
# Check new data frame
new_champions_df.head()
# Out:
#   Champion Name  Difficulty  Avg Element Score  Avg Stats Score  \
# 0         Galio           5               5.50       152.738636
# 1   TwistedFate           9               5.75       167.650091
# 2       XinZhao           2               4.75       137.527364
# 3         Urgot           8               6.00       159.225000
# 4       Leblanc           9               6.00       167.989545
#
#    Avg Stats per Level Score
# 0                  18.138889
# 1                  13.841111
# 2                  15.488889
# 3                  16.416667
# 4                  16.916667

# %%
 # Show new data frame statistics
 new_champions_df.describe()
# Out:
#        Difficulty  Avg Element Score  Avg Stats Score  \
# count  148.000000         148.000000       148.000000
# mean     5.790541           5.329392       151.280245
# std      2.097142           0.653378        21.958174
# min      1.000000           3.500000        95.338636
# 25%      4.000000           5.000000       135.853409
# 50%      6.000000           5.250000       147.253091
# 75%      7.000000           5.750000       171.855000
# max     10.000000           6.750000       184.444091
#
#        Avg Stats per Level Score
# count                 148.000000
# mean                   14.793126
# std                     2.102243
# min                     8.750000
# 25%                    13.820556
# 50%                    15.235556
# 75%                    16.251111
# max                    19.883333

# %%
 # Show new data frame data types
 new_champions_df.dtypes
# Out:
# Champion Name                 object
# Difficulty                     int64
# Avg Element Score            float64
# Avg Stats Score              float64
# Avg Stats per Level Score    float64
# dtype: object

# %%
# Champions sorted by difficulty level
sorted_new_champions_df = new_champions_df.sort_values(by='Difficulty', ascending=False)
sorted_new_champions_df
# Out:
#     Champion Name  Difficulty  Avg Element Score  Avg Stats Score  \
# 59         Rumble          10               6.75       117.431273
# 143      Aphelios          10               4.75       170.399091
# 25        Evelynn          10               5.75       135.906818
# 112         Yasuo          10               6.50       112.654273
# 31         Anivia          10               6.25       183.338273
# ..            ...         ...                ...              ...
# 2         XinZhao           2               4.75       137.527364
# 146          Sett           2               4.00       108.875000
# 89          Varus           2               4.00       175.014364
# 22        Morgana           1               4.00       164.829545
# 18    MissFortune           1               4.00       172.117091
#
#      Avg Stats per Level Score
# 59                   10.600000
# 143                  15.394444
# 25                   15.244444
# 112                  10.916667
# 31                   13.081111
# ..                         ...
# 2                    15.488889
# 146                  11.611111
# 89                   15.027778
# 22                   17.792222
# 18                   15.305556
#
# [148 rows x 5 columns]

# %%
# Champions sorted by avg stats per level
sorted_byLevel_champions_df = new_champions_df.sort_values(by='Avg Stats per Level Score', ascending=False)
sorted_byLevel_champions_df
# Out:
#     Champion Name  Difficulty  Avg Element Score  Avg Stats Score  \
# 141         Sylas           5               5.00       132.422273
# 35       Kassadin           8               6.00       143.553818
# 135         Ivern           7               5.50       178.431273
# 0           Galio           5               5.50       152.738636
# 22        Morgana           1               4.00       164.829545
# ..            ...         ...                ...              ...
# 145          Yone           8               6.00       154.375000
# 134        RekSai           3               4.50       120.024273
# 59         Rumble          10               6.75       117.431273
# 124          Kled           7               4.75        95.338636
# 110          Gnar           8               6.00       113.284091
#
#      Avg Stats per Level Score
# 141                  19.883333
# 35                   18.800000
# 135                  18.638889
# 0                    18.138889
# 22                   17.792222
# ..                         ...
# 145                  10.655556
# 134                  10.627778
# 59                   10.600000
# 124                   9.222222
# 110                   8.750000
#
# [148 rows x 5 columns]

# %%
# Calculate averages for avg element score
avg_score_df = new_champions_df.groupby(["Difficulty"]).mean()["Avg Element Score"]
avg_score_df
# Out:
# Difficulty
# 1     4.000000
# 2     4.458333
# 3     4.750000
# 4     4.956522
# 5     5.321429
# 6     5.412500
# 7     5.522727
# 8     5.625000
# 9     6.194444
# 10    6.000000
# Name: Avg Element Score, dtype: float64

# %%
# Calculate averages for avg stats
avg_stats_df = new_champions_df.groupby(["Difficulty"]).mean()["Avg Stats Score"]
avg_stats_df
# Out:
# Difficulty
# 1     168.473318
# 2     143.080364
# 3     139.115265
# 4     146.326407
# 5     150.479334
# 6     158.648959
# 7     154.750215
# 8     149.605418
# 9     164.802040
# 10    148.820818
# Name: Avg Stats Score, dtype: float64

# %%
# Calculate averages for avg stats per level
avg_statsperLevel_df = new_champions_df.groupby(["Difficulty"]).mean()["Avg Stats per Level Score"]
avg_statsperLevel_df
# Out:
# Difficulty
# 1     16.548889
# 2     14.741667
# 3     15.054583
# 4     14.297729
# 5     15.186210
# 6     15.097667
# 7     15.056449
# 8     14.102842
# 9     15.232901
# 10    13.461667
# Name: Avg Stats per Level Score, dtype: float64

# %%
# Sum all averages
Total_Score =  avg_score_df + avg_stats_df + avg_statsperLevel_df

# %%
# Assemble into DataFrame. 
difficulty_summary_df = pd.DataFrame({
          "Average Element Score": avg_score_df.map("{:.1f}".format),
          "Average Stats Score": avg_stats_df.map("{:.1f}".format),
          "Average Stats per Level Score": avg_statsperLevel_df.map("{:.1f}".format),
          "Total Score": Total_Score.map("{:.1f}".format)})

difficulty_summary_df
# Out:
#            Average Element Score Average Stats Score  \
# Difficulty
# 1                            4.0               168.5
# 2                            4.5               143.1
# 3                            4.8               139.1
# 4                            5.0               146.3
# 5                            5.3               150.5
# 6                            5.4               158.6
# 7                            5.5               154.8
# 8                            5.6               149.6
# 9                            6.2               164.8
# 10                           6.0               148.8
#
#            Average Stats per Level Score Total Score
# Difficulty
# 1                                   16.5       189.0
# 2                                   14.7       162.3
# 3                                   15.1       158.9
# 4                                   14.3       165.6
# 5                                   15.2       171.0
# 6                                   15.1       179.2
# 7                                   15.1       175.3
# 8                                   14.1       169.3
# 9                                   15.2       186.2
# 10                                  13.5       168.3

# %%
# Create new column names for new data frame
championsName = new_champions_df['Champion Name']
championsId = df_champions['key']
Role1 = df_champions['tag1']
Role2 = df_champions['tag2']
Difficulty = df_champions['difficulty']
AvgElementScore = new_champions_df['Avg Element Score']
AvgStatsScore = new_champions_df['Avg Stats Score']
AvgStatsperLevelScore	 = new_champions_df['Avg Stats per Level Score']
TotalScore = AvgElementScore + AvgStatsScore + AvgStatsperLevelScore
# NumberofSummons = champions_summary_df['Total Number of Summons']
# NumberofPoints = champions_summary_df['Total Number of Points']
# AvgChampionPoints = champions_summary_df['Avg Champion Points per Summon']

# %%
champions_difficulty_df = pd.DataFrame({
    'Champion Id': championsId,    
    "Champion Name": championsName,
    "Role 1": Role1,
    "Role 2": Role2,
    "Difficulty": Difficulty,
    "Average Element Score": AvgElementScore.map("{:.1f}".format),
    "Average Stats Score": AvgStatsScore.map("{:.1f}".format),
    "Average StatsperLevel Score": AvgStatsperLevelScore.map("{:.1f}".format),
    "Total Score": TotalScore.map("{:.1f}".format),
    # "Total Number of Summons": NumberofSummons,
    # "Total Number of Points": NumberofPoints,
    # "Average Points per Summon": AvgChampionPoints,
    })

champions_difficulty_df
# Out:
#      Champion Id Champion Name    Role 1    Role 2  Difficulty  \
# 0              3         Galio      Tank      Mage           5
# 1              4   TwistedFate      Mage       n/a           9
# 2              5       XinZhao   Fighter  Assassin           2
# 3              6         Urgot   Fighter      Tank           8
# 4              7       Leblanc  Assassin      Mage           9
# ..           ...           ...       ...       ...         ...
# 143          523      Aphelios  Marksman  Marksman          10
# 144          555          Pyke   Support  Assassin           7
# 145          777          Yone  Assassin   Fighter           8
# 146          875          Sett   Fighter      Tank           2
# 147          876        Lillia   Fighter      Mage           8
#
#     Average Element Score Average Stats Score Average StatsperLevel Score  \
# 0                     5.5               152.7                        18.1
# 1                     5.8               167.7                        13.8
# 2                     4.8               137.5                        15.5
# 3                     6.0               159.2                        16.4
# 4                     6.0               168.0                        16.9
# ..                    ...                 ...                         ...
# 143                   4.8               170.4                        15.4
# 144                   5.0               150.0                        16.8
# 145                   6.0               154.4                        10.7
# 146                   4.0               108.9                        11.6
# 147                   5.0               161.7                        16.9
#
#     Total Score
# 0         176.4
# 1         187.2
# 2         157.8
# 3         181.6
# 4         190.9
# ..          ...
# 143       190.5
# 144       171.7
# 145       171.0
# 146       124.5
# 147       183.7
#
# [148 rows x 9 columns]

# %%
TotalScore.describe()
# Out:
# count    148.000000
# mean     171.402763
# std       22.644649
# min      109.310859
# 25%      156.589503
# 50%      168.818616
# 75%      192.271419
# max      204.653535
# dtype: float64

# %%
# Establish the skill bins and group names.
skill_bins = [0, 165, 195, 205]
group_names = ["difficult", "intermediate", "easy"]

# %%
# Add Mastery Rank to dataframe
champions_difficulty_df["Mastery Rank"] = pd.cut(TotalScore, skill_bins, labels=group_names)
champions_difficulty_df.head()
# Out:
#    Champion Id Champion Name    Role 1    Role 2  Difficulty  \
# 0            3         Galio      Tank      Mage           5
# 1            4   TwistedFate      Mage       n/a           9
# 2            5       XinZhao   Fighter  Assassin           2
# 3            6         Urgot   Fighter      Tank           8
# 4            7       Leblanc  Assassin      Mage           9
#
#   Average Element Score Average Stats Score Average StatsperLevel Score  \
# 0                   5.5               152.7                        18.1
# 1                   5.8               167.7                        13.8
# 2                   4.8               137.5                        15.5
# 3                   6.0               159.2                        16.4
# 4                   6.0               168.0                        16.9
#
#   Total Score  Mastery Rank
# 0       176.4  intermediate
# 1       187.2  intermediate
# 2       157.8     difficult
# 3       181.6  intermediate
# 4       190.9  intermediate

# %%
# Create list of champions with Mastery rank 'Easy'
easyMasteryChampions = champions_difficulty_df[champions_difficulty_df['Mastery Rank'] == 'easy']
easyMasteryChampions.sort_values(by='Total Score', ascending=False)
# Out:
#      Champion Id Champion Name    Role 1    Role 2  Difficulty  \
# 6              9  Fiddlesticks      Mage   Support           9
# 104          134        Syndra      Mage   Support           8
# 101          127     Lissandra      Mage       n/a           6
# 130          268          Azir      Mage  Marksman           9
# 31            34        Anivia      Mage   Support          10
# 135          427         Ivern   Support      Mage           7
# 42            45        Veigar      Mage       n/a           7
# 94           115         Ziggs      Mage       n/a           4
# 107          142           Zoe      Mage   Support           5
# 96           119        Draven  Marksman  Marksman           8
# 142          518         Neeko      Mage   Support           5
# 56            63         Brand      Mage       n/a           4
# 44            50         Swain      Mage   Fighter           8
# 82           101        Xerath      Mage       n/a           8
# 113          161        Velkoz      Mage       n/a           8
# 23            26        Zilean   Support      Mage           6
# 108          143          Zyra      Mage   Support           7
# 81            99           Lux      Mage   Support           5
# 13            16        Soraka   Support      Mage           3
# 105          136   AurelionSol      Mage       n/a           7
# 114          163       Taliyah      Mage   Support           5
# 45            51       Caitlyn  Marksman  Marksman           6
# 109          145         Kaisa  Marksman  Marksman           6
# 84           103          Ahri      Mage  Assassin           5
# 10            13          Ryze      Mage   Fighter           7
# 69            81        Ezreal  Marksman      Mage           7
#
#     Average Element Score Average Stats Score Average StatsperLevel Score  \
# 6                     5.8               184.4                        14.5
# 104                   5.5               182.4                        15.6
# 101                   5.2               183.7                        14.4
# 130                   6.5               182.6                        13.8
# 31                    6.2               183.3                        13.1
# 135                   5.5               178.4                        18.6
# 42                    5.2               182.5                        14.5
# 94                    4.8               182.9                        14.0
# 107                   5.2               181.7                        14.2
# 96                    5.2               179.7                        15.6
# 142                   4.0               181.3                        14.7
# 56                    4.2               182.2                        13.2
# 44                    6.2               179.0                        13.8
# 82                    5.5               179.2                        13.7
# 113                   5.5               179.5                        13.2
# 23                    5.2               178.6                        13.6
# 108                   5.5               179.0                        12.6
# 81                    5.0               178.8                        13.2
# 13                    4.2               178.3                        13.8
# 105                   5.0               174.5                        16.9
# 114                   5.2               176.5                        14.5
# 45                    4.5               176.1                        15.6
# 109                   5.5               175.8                        14.9
# 84                    5.0               176.6                        14.2
# 10                    5.2               172.5                        17.6
# 69                    5.5               173.2                        16.5
#
#     Total Score Mastery Rank
# 6         204.7         easy
# 104       203.5         easy
# 101       203.3         easy
# 130       202.9         easy
# 31        202.7         easy
# 135       202.6         easy
# 42        202.2         easy
# 94        201.6         easy
# 107       201.2         easy
# 96        200.6         easy
# 142       199.9         easy
# 56        199.6         easy
# 44        199.1         easy
# 82        198.4         easy
# 113       198.2         easy
# 23        197.4         easy
# 108       197.1         easy
# 81        196.9         easy
# 13        196.4         easy
# 105       196.4         easy
# 114       196.3         easy
# 45        196.2         easy
# 109       196.2         easy
# 84        195.8         easy
# 10        195.4         easy
# 69        195.2         easy

# %%
intermMasteryChampions = champions_difficulty_df[champions_difficulty_df['Mastery Rank'] == 'intermediate']
intermMasteryChampions.sort_values(by='Total Score', ascending=False)
# Out:
#      Champion Id Champion Name    Role 1    Role 2  Difficulty  \
# 40            43         Karma      Mage   Support           5
# 60            69    Cassiopeia      Mage       n/a          10
# 121          235         Senna  Marksman      Mage           7
# 117          202          Jhin  Marksman      Mage           6
# 91           112        Viktor      Mage       n/a           9
# 139          498         Xayah  Marksman  Marksman           5
# 89           110         Varus  Marksman      Mage           2
# 26            29        Twitch  Marksman  Assassin           6
# 27            30       Karthus      Mage       n/a           7
# 53            60         Elise      Mage   Fighter           9
# 54            61       Orianna      Mage   Support           7
# 122          236        Lucian  Marksman  Marksman           6
# 137          432          Bard   Support      Mage           9
# 19            22          Ashe  Marksman      Mage           4
# 95           117          Lulu   Support      Mage           5
# 18            21   MissFortune  Marksman  Marksman           1
# 4              7       Leblanc  Assassin      Mage           9
# 143          523      Aphelios  Marksman  Marksman          10
# 39            42         Corki  Marksman  Marksman           6
# 62            74  Heimerdinger      Mage   Support           8
# 79            96        KogMaw  Marksman      Mage           6
# 64            76       Nidalee  Assassin      Mage           8
# 37            40         Janna   Support      Mage           7
# 76            90      Malzahar      Mage  Assassin           6
# 129          267          Nami   Support      Mage           5
# 119          222          Jinx  Marksman  Marksman           6
# 1              4   TwistedFate      Mage       n/a           9
# 22            25       Morgana      Mage   Support           1
# 12            15         Sivir  Marksman  Marksman           4
# 34            37          Sona   Support      Mage           4
# 131          350         Yuumi   Support      Mage           2
# 14            17         Teemo  Marksman  Assassin           6
# 85           104        Graves  Marksman  Marksman           3
# 147          876        Lillia   Fighter      Mage           8
# 136          429       Kalista  Marksman  Marksman           7
# 118          203       Kindred  Marksman  Marksman           4
# 103          133         Quinn  Marksman  Assassin           5
# 15            18      Tristana  Marksman  Assassin           4
# 3              6         Urgot   Fighter      Tank           8
# 132          412        Thresh   Support   Fighter           7
# 58            67         Vayne  Marksman  Assassin           8
# 73            85        Kennen      Mage  Marksman           4
# 0              3         Galio      Tank      Mage           5
# 106          141          Kayn   Fighter  Assassin           8
# 144          555          Pyke   Support  Assassin           7
# 145          777          Yone  Assassin   Fighter           8
# 138          497         Rakan   Support       n/a           5
# 90           111      Nautilus      Tank   Fighter           6
# 35            38      Kassadin  Assassin      Mage           8
# 92           113       Sejuani      Tank   Fighter           4
# 67            79        Gragas   Fighter      Mage           5
# 140          516          Ornn      Tank   Fighter           5
# 36            39        Irelia   Fighter  Assassin           5
# 120          223     TahmKench   Support      Tank           5
# 9             12       Alistar      Tank   Support           7
#
#     Average Element Score Average Stats Score Average StatsperLevel Score  \
# 40                    5.2               172.3                        17.3
# 60                    6.0               173.2                        15.5
# 121                   5.5               174.9                        14.3
# 117                   6.0               171.7                        17.0
# 91                    6.2               174.3                        14.0
# 139                   5.5               173.4                        15.5
# 89                    4.0               175.0                        15.0
# 26                    5.0               173.4                        15.2
# 27                    5.2               174.0                        14.2
# 53                    6.8               169.3                        17.0
# 54                    5.8               172.5                        14.1
# 122                   5.5               171.8                        15.0
# 137                   5.5               169.8                        16.6
# 19                    4.0               173.0                        14.5
# 95                    5.2               170.8                        15.5
# 18                    4.0               172.1                        15.3
# 4                     6.0               168.0                        16.9
# 143                   4.8               170.4                        15.4
# 39                    5.8               170.0                        14.5
# 62                    6.0               171.2                        12.9
# 79                    5.2               168.0                        15.7
# 64                    6.0               166.6                        15.8
# 37                    5.5               167.0                        16.0
# 76                    4.8               169.5                        13.8
# 129                   4.8               168.4                        14.2
# 119                   5.2               166.5                        15.7
# 1                     5.8               167.7                        13.8
# 22                    4.0               164.8                        17.8
# 12                    4.2               164.7                        16.6
# 34                    4.8               165.7                        14.7
# 131                   4.0               166.6                        13.7
# 14                    5.2               165.1                        13.5
# 85                    4.8               163.1                        16.0
# 147                   5.0               161.7                        16.9
# 136                   5.2               160.4                        17.6
# 118                   4.0               164.0                        14.5
# 103                   5.0               162.9                        14.5
# 15                    5.2               162.5                        14.4
# 3                     6.0               159.2                        16.4
# 132                   6.0               158.8                        16.1
# 58                    5.0               159.2                        14.9
# 73                    5.2               162.6                        10.7
# 0                     5.5               152.7                        18.1
# 106                   6.2               151.7                        16.4
# 144                   5.0               150.0                        16.8
# 145                   6.0               154.4                        10.7
# 138                   4.8               148.2                        16.4
# 90                    5.5               147.9                        15.9
# 35                    6.0               143.6                        18.8
# 92                    5.5               145.3                        17.2
# 67                    5.5               145.3                        17.1
# 140                   5.5               144.8                        16.9
# 36                    5.2               146.7                        15.3
# 120                   5.8               144.1                        16.9
# 9                     6.8               141.9                        17.6
#
#     Total Score  Mastery Rank
# 40        194.9  intermediate
# 60        194.7  intermediate
# 121       194.7  intermediate
# 117       194.7  intermediate
# 91        194.6  intermediate
# 139       194.3  intermediate
# 89        194.0  intermediate
# 26        193.6  intermediate
# 27        193.5  intermediate
# 53        193.0  intermediate
# 54        192.3  intermediate
# 122       192.3  intermediate
# 137       191.9  intermediate
# 19        191.5  intermediate
# 95        191.5  intermediate
# 18        191.4  intermediate
# 4         190.9  intermediate
# 143       190.5  intermediate
# 39        190.3  intermediate
# 62        190.1  intermediate
# 79        188.9  intermediate
# 64        188.4  intermediate
# 37        188.4  intermediate
# 76        188.1  intermediate
# 129       187.4  intermediate
# 119       187.4  intermediate
# 1         187.2  intermediate
# 22        186.6  intermediate
# 12        185.6  intermediate
# 34        185.1  intermediate
# 131       184.3  intermediate
# 14        183.9  intermediate
# 85        183.8  intermediate
# 147       183.7  intermediate
# 136       183.2  intermediate
# 118       182.5  intermediate
# 103       182.4  intermediate
# 15        182.1  intermediate
# 3         181.6  intermediate
# 132       180.9  intermediate
# 58        179.1  intermediate
# 73        178.6  intermediate
# 0         176.4  intermediate
# 106       174.3  intermediate
# 144       171.7  intermediate
# 145       171.0  intermediate
# 138       169.4  intermediate
# 90        169.3  intermediate
# 35        168.4  intermediate
# 92        168.0  intermediate
# 67        167.9  intermediate
# 140       167.2  intermediate
# 36        167.2  intermediate
# 120       166.8  intermediate
# 9         166.2  intermediate

# %%
difficultMasteryChampions = champions_difficulty_df[champions_difficulty_df['Mastery Rank'] == 'difficult']
difficultMasteryChampions.sort_values(by='Total Score', ascending=False)
# Out:
#      Champion Id Champion Name    Role 1    Role 2  Difficulty  \
# 43            48       Trundle   Fighter      Tank           5
# 7             10         Kayle   Fighter   Support           7
# 77            91         Talon  Assassin       n/a           7
# 102          131         Diana   Fighter      Mage           4
# 87           106      Volibear   Fighter      Tank           3
# ..           ...           ...       ...       ...         ...
# 88           107        Rengar  Assassin   Fighter           8
# 33            36       DrMundo   Fighter      Tank           5
# 146          875          Sett   Fighter      Tank           2
# 78            92         Riven   Fighter  Assassin           8
# 124          240          Kled   Fighter      Tank           7
#
#     Average Element Score Average Stats Score Average StatsperLevel Score  \
# 43                    5.0               143.0                        16.9
# 7                     6.5               142.1                        16.0
# 77                    5.0               143.5                        16.0
# 102                   6.2               143.3                        14.6
# 87                    5.2               141.7                        16.8
# ..                    ...                 ...                         ...
# 88                    5.2               109.2                        11.2
# 33                    5.8               108.2                        11.2
# 146                   4.0               108.9                        11.6
# 78                    5.5               105.7                        10.8
# 124                   4.8                95.3                         9.2
#
#     Total Score Mastery Rank
# 43        164.9    difficult
# 7         164.6    difficult
# 77        164.6    difficult
# 102       164.2    difficult
# 87        163.8    difficult
# ..          ...          ...
# 88        125.6    difficult
# 33        125.2    difficult
# 146       124.5    difficult
# 78        122.1    difficult
# 124       109.3    difficult
#
# [67 rows x 10 columns]

# %%
# List most difficult champions
mostdifficultChampions = champions_difficulty_df[(champions_difficulty_df['Difficulty'] == 10) 
                                             & (champions_difficulty_df['Mastery Rank'] == 'difficult')]

mostdifficultChampions
# Out:
#      Champion Id Champion Name    Role 1    Role 2  Difficulty  \
# 25            28       Evelynn  Assassin      Mage          10
# 59            68        Rumble   Fighter      Mage          10
# 112          157         Yasuo   Fighter  Assassin          10
#
#     Average Element Score Average Stats Score Average StatsperLevel Score  \
# 25                    5.8               135.9                        15.2
# 59                    6.8               117.4                        10.6
# 112                   6.5               112.7                        10.9
#
#     Total Score Mastery Rank
# 25        156.9    difficult
# 59        134.8    difficult
# 112       130.1    difficult

# %%
# List difficult champions

difficultChampions = champions_difficulty_df[(champions_difficulty_df['Difficulty'] == 9) 
                                             & (champions_difficulty_df['Mastery Rank'] == 'difficult')]

difficultChampions
# Out:
#     Champion Id Champion Name    Role 1 Role 2  Difficulty  \
# 32           35         Shaco  Assassin    n/a           9
# 38           41     Gangplank   Fighter    n/a           9
#
#    Average Element Score Average Stats Score Average StatsperLevel Score  \
# 32                   6.8               136.4                        15.6
# 38                   6.5               130.7                        14.9
#
#    Total Score Mastery Rank
# 32       158.8    difficult
# 38       152.0    difficult

# %%
# List most easiest champions

mostEasiestChampions = champions_difficulty_df[(champions_difficulty_df['Difficulty'] == 3) 
                                             & (champions_difficulty_df['Mastery Rank'] == 'easy')]

mostEasiestChampions
# Out:
#     Champion Id Champion Name   Role 1 Role 2  Difficulty  \
# 13           16        Soraka  Support   Mage           3
#
#    Average Element Score Average Stats Score Average StatsperLevel Score  \
# 13                   4.2               178.3                        13.8
#
#    Total Score Mastery Rank
# 13       196.4         easy

# %%
EasyChampions = champions_difficulty_df[(champions_difficulty_df['Difficulty'] == 4) 
                                             & (champions_difficulty_df['Mastery Rank'] == 'easy')]

EasyChampions
# Out:
#     Champion Id Champion Name Role 1 Role 2  Difficulty Average Element Score  \
# 56           63         Brand   Mage    n/a           4                   4.2
# 94          115         Ziggs   Mage    n/a           4                   4.8
#
#    Average Stats Score Average StatsperLevel Score Total Score Mastery Rank
# 56               182.2                        13.2       199.6         easy
# 94               182.9                        14.0       201.6         easy

# %%
cur.close() 
conn.commit()
